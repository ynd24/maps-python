# %%
import pandas

# %%
data = pandas.read_csv("Webmap_datasources/Volcanoes.txt")
data
# Out:
#     VOLCANX020    NUMBER            NAME       LOCATION  \
# 0        509.0  1201-01=           Baker  US-Washington
# 1        511.0  1201-02-    Glacier Peak  US-Washington
# 2        513.0  1201-03-         Rainier  US-Washington
# 3        515.0  1201-05-      St. Helens  US-Washington
# 4        516.0  1201-04-           Adams  US-Washington
# ..         ...       ...             ...            ...
# 57       580.0  1210-03-  Valles Caldera  US-New Mexico
# 58       581.0  1209-02-   Sunset Crater     US-Arizona
# 59       584.0  1203-20-           Amboy  US-California
# 60       586.0  1210-02-    Zuni-Bandera  US-New Mexico
# 61       588.0  1210-01-       Carrizozo  US-New Mexico
#
#                    STATUS    ELEV             TYPE TIMEFRAME        LAT  \
# 0              Historical  3285.0  Stratovolcanoes        D3  48.776798
# 1        Tephrochronology  3213.0    Stratovolcano        D4  48.111801
# 2        Dendrochronology  4392.0    Stratovolcano        D3  46.869801
# ...

# %%
lat = data["LAT"]
lat
# Out:
# 0     48.776798
# 1     48.111801
# 2     46.869801
# 3     46.199799
# 4     46.205799
#         ...
# 57    35.869999
# 58    35.369999
# 59    34.549999
# 60    34.799999
# 61    33.780102
# Name: LAT, Length: 62, dtype: float64

# %%
len(lat)
# Out:
# 62

# %%
lon = data["LON"]
len(lon)
# Out:
# 62

# %%
lat
# Out:
# 0     48.776798
# 1     48.111801
# 2     46.869801
# 3     46.199799
# 4     46.205799
#         ...
# 57    35.869999
# 58    35.369999
# 59    34.549999
# 60    34.799999
# 61    33.780102
# Name: LAT, Length: 62, dtype: float64

# %%
list(lat)
# Out:
# [48.7767982,
#  48.1118011,
#  46.8698006,
#  46.1997986,
#  46.2057991,
#  45.8797989,
#  45.9297981,
#  45.3737984,
#  44.6917992,
#  44.4197998,
#  44.3797989,
#  44.3317986,
#  44.2848015,
#  44.1697998,
#  44.0998001,
#  43.9788017,
#  43.7218018,
#  43.5698013,
#  43.5119019,
#  43.240799,
#  43.4719009,
#  43.3609009,
#  42.9299011,
#  44.4299011,
#  43.0998993,
#  43.1498985,
#  42.9999008,
#  43.419899,
#  43.4999008,
#  43.1799011,
#  42.6058998,
#  41.5798988,
#  42.8799019,
#  41.419899,
#  41.1778984,
#  40.9548988,
#  40.7798996,
#  40.6799011,
#  40.6299019,
#  40.4919014,
#  38.9698982,
#  39.3749008,
#  39.6500015,
#  37.9999008,
#  38.9700012,
#  37.8799019,
#  37.6918983,
#  37.6999016,
#  37.5798988,
#  37.0199013,
#  37.5800018,
#  37.257,
#  37.3279991,
#  36.3578987,
#  36.0298996,
#  36.3800011,
#  34.75,
#  35.8699989,
#  35.3699989,
#  34.5499992,
#  34.7999992,
#  33.7801018]

# %%
import pandas as pd

# %%
df = pd.read_csv("Webmap_datasources/volc.csv", sep=";")

# %%
df
# Out:
#      Year  Month   Day Flag Tsunami Flag Earthquake     Volcano Name  \
# 0    -141    NaN   NaN          NaN             NaN             Etna
# 1    1262    NaN   NaN          NaN             NaN            Katla
# 2    1300    7.0  11.0          NaN             NaN            Hekla
# 3    1331   12.0   NaN          NaN             NaN              Aso
# 4    1714    6.0  30.0      Tsunami             NaN         Vesuvius
# ..    ...    ...   ...          ...             ...              ...
# 830  2006    5.0  20.0      Tsunami             NaN  Soufriere Hills
# 831  2015    4.0  22.0          NaN             NaN          Calbuco
# 832  2017    9.0  12.0          NaN             NaN    Campi Flegrei
# 833  2018    1.0   5.0          NaN             NaN          Kadovar
# 834  2018    3.0  21.0          NaN             NaN             Ijen
#
#              Location           Country  Elevation        Volcano Type  ...  \
# ...

# %%
df
# Out:
#      Year  Month   Day Flag Tsunami Flag Earthquake     Volcano Name  \
# 0    -141    NaN   NaN          NaN             NaN             Etna
# 1    1262    NaN   NaN          NaN             NaN            Katla
# 2    1300    7.0  11.0          NaN             NaN            Hekla
# 3    1331   12.0   NaN          NaN             NaN              Aso
# 4    1714    6.0  30.0      Tsunami             NaN         Vesuvius
# ..    ...    ...   ...          ...             ...              ...
# 830  2006    5.0  20.0      Tsunami             NaN  Soufriere Hills
# 831  2015    4.0  22.0          NaN             NaN          Calbuco
# 832  2017    9.0  12.0          NaN             NaN    Campi Flegrei
# 833  2018    1.0   5.0          NaN             NaN          Kadovar
# 834  2018    3.0  21.0          NaN             NaN             Ijen
#
#              Location           Country  Elevation        Volcano Type  ...  \
# ...

# %%
coord = list(df["Coordinates"])

# %%
print(coord)
# Out:
# ['37.734,15.004', '63.63,-19.05', '63.98,-19.7', '32.88,131.1', '40.821,14.426', '-13.612,-172.525', '36.4,138.53', '19.514,-103.62', '52.82,-169.95', '32.1,139.85', '-40.59,-72.117', '28.58,-17.83', '-5.52,148.121', '13.33,-61.18', '34.08,139.53', '37.734,15.004', '32.88,131.1', '37.734,15.004', '-8.108,112.92', '-6.72,106.73', '14.473,-90.88', '-15.4,167.83', '-15.4,167.83', '38.789,15.213', '-8.125,114.042', '25.32,98.47', '-6.3,130.0', '38.47,-28.4', '-38.82,176.0', '36.404,25.396', '19.475,-155.608', '-6.14,155.195', '-15.6,-175.63', '31.93,130.87', '14.82,-61.17', '-15.4,167.83', '-7.32,107.73', '36.404,25.396', '36.53,139.18', '-8.342,115.508', '-8.108,112.92', '14.002,120.993', '63.43,-20.28', '2.78,125.48', '19.425,-155.292', '17.36,-93.228', '6.25,10.5', '-8.108,112.92', '-19.52,169.425', '12.702,-87.004', '-7.942,112.95', '2.92,-76.05', '-42.833,-72.646', '52.18,-175.5', '-7.542,110.442', '11.984,-86.161', '40.821,14.426', '40.821,14.426', '17.36,-93.228', '-7.93,112.308',
# ...

# %%
import re

# %%
lat = []
long = []

# %%
Coord = []

# %%
for c in coord:
    x = re.split(",", c)
    Coord.append(x)

# %%
lat3 = []
long3 = []
for lat_long in Coord:
    lat3.append(float(lat_long[0]))
    long3.append(float(lat_long[1]))

# %%
coordinate_2 = Coord.copy()

# %%
for sublist in coordinate_2:
    for element in sublist:
        if sublist.index(element) == 1:
            long.append(element)
        else:
            lat.append(element)

# %%
print(type(lat[30]))
# Out:
# <class 'str'>

# %%
lat_f = [float(i) for i in lat]
long_f = [float(i) for i in long]

# %%
print(lat3)
# Out:
# [37.734, 63.63, 63.98, 32.88, 40.821, -13.612, 36.4, 19.514, 52.82, 32.1, -40.59, 28.58, -5.52, 13.33, 34.08, 37.734, 32.88, 37.734, -8.108, -6.72, 14.473, -15.4, -15.4, 38.789, -8.125, 25.32, -6.3, 38.47, -38.82, 36.404, 19.475, -6.14, -15.6, 31.93, 14.82, -15.4, -7.32, 36.404, 36.53, -8.342, -8.108, 14.002, 63.43, 2.78, 19.425, 17.36, 6.25, -8.108, -19.52, 12.702, -7.942, 2.92, -42.833, 52.18, -7.542, 11.984, 40.821, 40.821, 17.36, -7.93, 40.827, 32.75, -0.677, 0.8, 13.257, 42.53, -7.25, 0.8, 34.08, 10.0, -8.108, 38.789, -7.2, 12.77, 42.53, -39.28, -7.93, -2.751, 38.73, -45.9, -8.54, -4.649, 37.734, 17.36, 1.22, 37.734, 2.92, -40.59, -38.12, 35.9, 0.8, 13.257, -4.1, 15.63, 27.08, 37.734, -16.608, 64.42, 64.63, 48.292, 34.73, 40.821, -7.13, 4.914, 24.0, 32.88, -8.108, 9.203, 65.03, -1.467, -38.12, -41.326, 9.203, 32.1, 32.75, -8.108, -7.125, 15.13, 10.412, 13.257, 37.734, -7.2, 56.17, 61.38, 21.125, 63.98, 37.734, 63.98, -4.525, 14.473, 0.32, 28.58, 19.692, 46.2, -4.525, 53.255, 37.
# ...
